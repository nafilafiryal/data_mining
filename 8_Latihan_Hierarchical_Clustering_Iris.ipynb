# %% [markdown]
# <a href="https://colab.research.google.com/github/nafilafiryal/data_mining/blob/main/8_Latihan_Hierarchical_Clustering_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv('/content/drive/My Drive/dataMining/Iris.csv')

print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# After running the above cell, you will be prompted to authorize Google Drive access. Follow the steps in the pop-up window or the link provided in the output to complete the authorization. Once mounted, your Drive files will be accessible under `/content/drive/My Drive/`.

# %%
X = df[['SepalLengthCm',
        'SepalWidthCm',
        'PetalLengthCm',
        'PetalWidthCm']]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
agg_clust = AgglomerativeClustering(n_clusters=3)

df['Agg_Cluster'] = agg_clust.fit_predict(X_scaled)

print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Agg_Cluster
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x=df['PetalLengthCm'],
    y=df['PetalWidthCm'],
    hue=df['Agg_Cluster'],
    palette='viridis'
)

plt.title('Hasil Agglomerative Clustering pada Data Iris')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.grid(True)

plt.show()
