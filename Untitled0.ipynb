# %% [markdown]
# <a href="https://colab.research.google.com/github/nafilafiryal/data_mining/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nafilafiryal/data_mining.git
# Out:
# Cloning into 'data_mining'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd data_mining/
# Out:
# /content/data_mining

# %%
# !mkdir week4

# %%
# !mv Untitled0.ipynb week4/
# Out:
# mv: cannot stat 'Untitled0.ipynb': No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# %cd..
# Out:
# UsageError: Line magic function `%cd..` not found.

# %%
# !ls
# Out:
# sample_data

# %%
# %cd /content
# !ls
# Out:
# /content
# sample_data

# %%
# !git clone https://github.com/nafilafiryal/data_mining.git
# Out:
# Cloning into 'data_mining'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd data_mining
# !ls
# Out:
# /content/data_mining
# README.md  Untitled0.ipynb

# %%
# !mkdir -p week4

# %%
# %cd /content
# !ls
# Out:
# /content
# data_mining  sample_data

# %%
# %cd data_mining
# !ls
# Out:
# /content/data_mining
# README.md  Untitled0.ipynb  week4

# %%
# !mv Untitled0.ipynb week4/

# %%
# !ls week4
# Out:
# Untitled0.ipynb

# %%
# !mv Untitled0.ipynb week4/CleaningData.ipynb
# Out:
# mv: cannot stat 'Untitled0.ipynb': No such file or directory

# %%
# !mv week4/Untitled0.ipynb week4/CleaningData.ipynb

# %%
# !ls week4
# Out:
# CleaningData.ipynb
